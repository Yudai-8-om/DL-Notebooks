# %% [markdown]
# ## MNIST CNN

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *

# %% [markdown]
# ### Data

# %%
data_dir = base_dir + 'data'
path = untar_data(URLs.MNIST, dest = data_dir)

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/testing'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training')]

# %%
il = ImageList.from_folder(path, convert_mode='L')

# %%
il.items[0]
# Out:
# PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/testing/2/995.png')

# %%
defaults.cmap='binary'

# %%
il
# Out:
# ImageList (70000 items)
# Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28)
# Path: /content/gdrive/My Drive/fastai-v3/data/mnist_png

# %%
il[0].show()

# %%
sd = il.split_by_folder(train='training', valid='testing')

# %%
sd
# Out:
# ItemLists;
#
# Train: ImageList (60000 items)
# Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28)
# Path: /content/gdrive/My Drive/fastai-v3/data/mnist_png;
#
# Valid: ImageList (10000 items)
# Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28)
# Path: /content/gdrive/My Drive/fastai-v3/data/mnist_png;
#
# Test: None

# %%
(path/'training').ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/2'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/7'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/9'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/8'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/5'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/3'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/4'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/6'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/0'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/mnist_png/training/1')]

# %%
ll = sd.label_from_folder()

# %%
ll
# Out:
# LabelLists;
#
# Train: LabelList (60000 items)
# x: ImageList
# Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28)
# y: CategoryList
# 2,2,2,2,2
# Path: /content/gdrive/My Drive/fastai-v3/data/mnist_png;
#
# Valid: LabelList (10000 items)
# x: ImageList
# Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28),Image (1, 28, 28)
# y: CategoryList
# 2,2,2,2,2
# Path: /content/gdrive/My Drive/fastai-v3/data/mnist_png;
#
# Test: None

# %%
x,y = ll.train[0]

# %%
x.show()
print(y,x.shape)
# Out:
# 2 torch.Size([1, 28, 28])

# %%
tfms = ([*rand_pad(padding=3, size=28, mode='zeros')], [])

# %%
ll = ll.transform(tfms)

# %%
bs = 128

# %%
# not using imagenet_stats because not using pretrained model
data = ll.databunch(bs=bs).normalize()

# %%
x,y = data.train_ds[0]

# %%
x.show()
print(y)
# Out:
# 2

# %%
def _plot(i,j,ax): data.train_ds[0][0].show(ax, cmap='gray')
plot_multi(_plot, 3, 3, figsize=(8,8))

# %%
xb,yb = data.one_batch()
xb.shape,yb.shape
# Out:
# (torch.Size([128, 1, 28, 28]), torch.Size([128]))

# %%
data.show_batch(rows=3, figsize=(5,5))

# %% [markdown]
# ### Basic CNN with batchnorm

# %%
def conv(ni,nf): return nn.Conv2d(ni, nf, kernel_size=3, stride=2, padding=1)

# %%
model = nn.Sequential(
    conv(1, 8), # 14
    nn.BatchNorm2d(8),
    nn.ReLU(),
    conv(8, 16), # 7
    nn.BatchNorm2d(16),
    nn.ReLU(),
    conv(16, 32), # 4
    nn.BatchNorm2d(32),
    nn.ReLU(),
    conv(32, 16), # 2
    nn.BatchNorm2d(16),
    nn.ReLU(),
    conv(16, 10), # 1
    nn.BatchNorm2d(10),
    Flatten()     # remove (1,1) grid
)

# %%
learn = Learner(data, model, loss_func = nn.CrossEntropyLoss(), metrics=accuracy)

# %%
print(learn.summary())
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [8, 14, 14]          80         True
# ______________________________________________________________________
# BatchNorm2d          [8, 14, 14]          16         True
# ______________________________________________________________________
# ReLU                 [8, 14, 14]          0          False
# ______________________________________________________________________
# Conv2d               [16, 7, 7]           1,168      True
# ______________________________________________________________________
# BatchNorm2d          [16, 7, 7]           32         True
# ______________________________________________________________________
# ReLU                 [16, 7, 7]           0          False
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           4,640      True
# ______________________________________________________________________
# BatchNorm2d          [32, 4, 4]           64         True
# ______________________________________________________________________
# ReLU                 [32, 4, 4]           0          False
# ______________________________________________________________________
# Conv2d               [16, 2, 2]           4,624      True
# ______________________________________________________________________
# BatchNorm2d          [16, 2, 2]           32         True
# ______________________________________________________________________
# ReLU                 [16, 2, 2]           0          False
# ______________________________________________________________________
# Conv2d               [10, 1, 1]           1,450      True
# ______________________________________________________________________
# BatchNorm2d          [10, 1, 1]           20         True
# ______________________________________________________________________
# Flatten              [10]                 0          False
# ______________________________________________________________________
#
# Total params: 12,126
# Total trainable params: 12,126
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : CrossEntropyLoss
# ======================================================================
# Callbacks functions applied

# %%
xb = xb.cuda()

# %%
model(xb).shape
# Out:
# torch.Size([128, 10])

# %%
learn.lr_find(end_lr=100)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(3, max_lr=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.225167</td>
#       <td>0.203332</td>
#       <td>0.941300</td>
#       <td>03:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.128788</td>
#       <td>0.074879</td>
#       <td>0.976300</td>
#       <td>03:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.072059</td>
#       <td>0.040534</td>
#       <td>0.987000</td>
#       <td>03:26</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Refactor

# %%
def conv2(ni,nf): return conv_layer(ni,nf,stride=2)

# %%
model = nn.Sequential(
    conv2(1, 8),   # 14
    conv2(8, 16),  # 7
    conv2(16, 32), # 4
    conv2(32, 16), # 2
    conv2(16, 10), # 1
    Flatten()      # remove (1,1) grid
)

# %%
learn = Learner(data, model, loss_func = nn.CrossEntropyLoss(), metrics=accuracy)

# %%
learn.fit_one_cycle(10, max_lr=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.233917</td>
#       <td>0.358974</td>
#       <td>0.898400</td>
#       <td>03:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.198395</td>
#       <td>0.131488</td>
#       <td>0.958200</td>
#       <td>03:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.172732</td>
#       <td>0.240890</td>
#       <td>0.922500</td>
#       <td>03:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.138558</td>
#       <td>0.098186</td>
#       <td>0.968700</td>
#       <td>03:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.118289</td>
#       <td>0.066798</td>
#       <td>0.978500</td>
#       <td>03:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.116103</td>
#       <td>0.104203</td>
#       <td>0.968900</td>
#       <td>03:26</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.092312</td>
#       <td>0.053283</td>
#       <td>0.984000</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.070400</td>
#       <td>0.037551</td>
#       <td>0.988700</td>
#       <td>03:25</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.052234</td>
#       <td>0.028079</td>
#       <td>0.991400</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.049199</td>
#       <td>0.027346</td>
#       <td>0.991700</td>
#       <td>03:23</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Resnet-ish

# %%
class ResBlock(nn.Module):
    def __init__(self, nf):
        super().__init__()
        self.conv1 = conv_layer(nf,nf)
        self.conv2 = conv_layer(nf,nf)
        
    def forward(self, x): return x + self.conv2(self.conv1(x))

# %%
help(res_block)
# Out:
# Help on function res_block in module fastai.layers:
#
# res_block(nf, dense:bool=False, norm_type:Union[fastai.layers.NormType, NoneType]=<NormType.Batch: 1>, bottle:bool=False, **conv_kwargs)
#     Resnet block of `nf` features. `conv_kwargs` are passed to `conv_layer`.

# %%
model = nn.Sequential(
    conv2(1, 8),
    res_block(8),
    conv2(8, 16),
    res_block(16),
    conv2(16, 32),
    res_block(32),
    conv2(32, 16),
    res_block(16),
    conv2(16, 10),
    Flatten()
)

# %%
 def conv_and_res(ni,nf): return nn.Sequential(conv2(ni, nf), res_block(nf))

# %%
model = nn.Sequential(
    conv_and_res(1, 8),
    conv_and_res(8, 16),
    conv_and_res(16, 32),
    conv_and_res(32, 16),
    conv2(16, 10),
    Flatten()
)

# %%
learn = Learner(data, model, loss_func = nn.CrossEntropyLoss(), metrics=accuracy)

# %%
learn.lr_find(end_lr=100)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(12, max_lr=0.05)
# Out:
# Total time: 02:00 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.248807</th>
#     <th>0.121582</th>
#     <th>0.972800</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.120927</th>
#     <th>0.360583</th>
#     <th>0.890300</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.104013</th>
#     <th>0.074916</th>
#     <th>0.977800</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.081181</th>
#     <th>0.065717</th>
#     <th>0.980000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.068514</th>
#     <th>0.096448</th>
#     <th>0.967200</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.061274</th>
#     <th>0.087955</th>
#     <th>0.971800</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.051673</th>
#     <th>0.033911</th>
#     <th>0.989400</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.048090</th>
#     <th>0.033234</th>
#     <th>0.988800</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.039095</th>
#     <th>0.024638</th>
#     <th>0.992400</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.023670</th>
#     <th>0.021215</th>
#     <th>0.993400</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.019128</th>
#     <th>0.016159</th>
#     <th>0.994500</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.021365</th>
#     <th>0.016120</th>
#     <th>0.995200</th>
#   </tr>
# </table>

# %%
print(learn.summary())
# Out:
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [128, 8, 14, 14]     72         True
# ______________________________________________________________________
# ReLU                 [128, 8, 14, 14]     0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 14, 14]     16         True
# ______________________________________________________________________
# Conv2d               [128, 8, 14, 14]     576        True
# ______________________________________________________________________
# ReLU                 [128, 8, 14, 14]     0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 14, 14]     16         True
# ______________________________________________________________________
# Conv2d               [128, 8, 14, 14]     576        True
# ______________________________________________________________________
# ReLU                 [128, 8, 14, 14]     0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 14, 14]     16         True
# ______________________________________________________________________
# MergeLayer           [128, 8, 14, 14]     0          False
# ______________________________________________________________________
# Conv2d               [128, 16, 7, 7]      1152       True
# ______________________________________________________________________
# ReLU                 [128, 16, 7, 7]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 7, 7]      32         True
# ______________________________________________________________________
# Conv2d               [128, 16, 7, 7]      2304       True
# ______________________________________________________________________
# ReLU                 [128, 16, 7, 7]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 7, 7]      32         True
# ______________________________________________________________________
# Conv2d               [128, 16, 7, 7]      2304       True
# ______________________________________________________________________
# ReLU                 [128, 16, 7, 7]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 7, 7]      32         True
# ______________________________________________________________________
# MergeLayer           [128, 16, 7, 7]      0          False
# ______________________________________________________________________
# Conv2d               [128, 32, 4, 4]      4608       True
# ______________________________________________________________________
# ReLU                 [128, 32, 4, 4]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 4, 4]      64         True
# ______________________________________________________________________
# Conv2d               [128, 32, 4, 4]      9216       True
# ______________________________________________________________________
# ReLU                 [128, 32, 4, 4]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 4, 4]      64         True
# ______________________________________________________________________
# Conv2d               [128, 32, 4, 4]      9216       True
# ______________________________________________________________________
# ReLU                 [128, 32, 4, 4]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 4, 4]      64         True
# ______________________________________________________________________
# MergeLayer           [128, 32, 4, 4]      0          False
# ______________________________________________________________________
# Conv2d               [128, 16, 2, 2]      4608       True
# ______________________________________________________________________
# ReLU                 [128, 16, 2, 2]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 2, 2]      32         True
# ______________________________________________________________________
# Conv2d               [128, 16, 2, 2]      2304       True
# ______________________________________________________________________
# ReLU                 [128, 16, 2, 2]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 2, 2]      32         True
# ______________________________________________________________________
# Conv2d               [128, 16, 2, 2]      2304       True
# ______________________________________________________________________
# ReLU                 [128, 16, 2, 2]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 2, 2]      32         True
# ______________________________________________________________________
# MergeLayer           [128, 16, 2, 2]      0          False
# ______________________________________________________________________
# Conv2d               [128, 10, 1, 1]      1440       True
# ______________________________________________________________________
# ReLU                 [128, 10, 1, 1]      0          False
# ______________________________________________________________________
# BatchNorm2d          [128, 10, 1, 1]      20         True
# ______________________________________________________________________
# Flatten              [128, 10]            0          False
# ______________________________________________________________________
#
# Total params: 41132
# Total trainable params: 41132
# Total non-trainable params: 0

# %% [markdown]
# ## fin
