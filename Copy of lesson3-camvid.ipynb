# %% [markdown]
# ## Image segmentation with CamVid

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
data_dir = Path(base_dir + 'data')
path = untar_data(URLs.CAMVID, dest=data_dir)
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/codes.txt'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/images'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/valid.txt'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/labels')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/images/0016E5_00750.png'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/images/0006R0_f00990.png'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/images/0016E5_07410.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/labels/0001TP_009690_P.png'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/labels/0016E5_08073_P.png'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/camvid/labels/0016E5_04470_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[21, 21, 21,  ..., 21, 21, 21],
#           [21, 21, 21,  ..., 21, 21, 21],
#           [21, 21, 21,  ..., 21, 21, 21],
#           ...,
#           [18, 18, 18,  ..., 17, 17, 17],
#           [18, 18, 18,  ..., 17, 17, 17],
#           [18, 18, 18,  ..., 17, 17, 17]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 11430MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torch.nn.functional")

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:03<00:00, 23.1MB/s]

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.308343</td>
#       <td>0.899763</td>
#       <td>0.801178</td>
#       <td>03:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.883690</td>
#       <td>0.654107</td>
#       <td>0.837959</td>
#       <td>03:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.724395</td>
#       <td>0.597931</td>
#       <td>0.849173</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.656748</td>
#       <td>0.608136</td>
#       <td>0.835692</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.616025</td>
#       <td>0.514640</td>
#       <td>0.864089</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.701338</td>
#       <td>0.488241</td>
#       <td>0.861353</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.606811</td>
#       <td>0.527500</td>
#       <td>0.859098</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.559938</td>
#       <td>0.499765</td>
#       <td>0.874693</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.545106</td>
#       <td>0.425878</td>
#       <td>0.880416</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.475915</td>
#       <td>0.366029</td>
#       <td>0.900014</td>
#       <td>03:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lrs = slice(lr/400,lr/4)# from the graph I got 3e-5, lr/5

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.408372</td>
#       <td>0.350944</td>
#       <td>0.899112</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.399363</td>
#       <td>0.340049</td>
#       <td>0.902964</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.391575</td>
#       <td>0.344809</td>
#       <td>0.901340</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.383356</td>
#       <td>0.319557</td>
#       <td>0.910619</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.378082</td>
#       <td>0.329454</td>
#       <td>0.905285</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.362981</td>
#       <td>0.315810</td>
#       <td>0.913466</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.356179</td>
#       <td>0.313089</td>
#       <td>0.908171</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.348849</td>
#       <td>0.313435</td>
#       <td>0.911840</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.343801</td>
#       <td>0.321664</td>
#       <td>0.910350</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.328483</td>
#       <td>0.378641</td>
#       <td>0.887165</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.310839</td>
#       <td>0.293233</td>
#       <td>0.919185</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.283985</td>
#       <td>0.278595</td>
#       <td>0.921966</td>
#       <td>03:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_lr()

# %%
learn.save('stage-2')

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# this Learner object self-destroyed - it still exists, but no longer usable
# using bs=1, have 7433MB of GPU RAM free

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [4/10 56:12<1:24:18]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.491287</td>
#       <td>0.353569</td>
#       <td>0.900872</td>
#       <td>14:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.412560</td>
#       <td>0.310644</td>
#       <td>0.912515</td>
#       <td>14:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.397362</td>
#       <td>0.401678</td>
#       <td>0.882973</td>
#       <td>14:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.422469</td>
#       <td>0.407837</td>
#       <td>0.886604</td>
#       <td>13:58</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='323' class='' max='600', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.83% [323/600 07:05<06:05 0.3777]
#     </div>

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lr_find(learn)
learn.recorder.plot()

# %%
lrs = slice(1e-6,lr/5)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# Total time: 21:05 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>acc_camvid</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.225999</th>
#     <th>0.254650</th>
#     <th>0.930782</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.216341</th>
#     <th>0.256007</th>
#     <th>0.930751</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.209800</th>
#     <th>0.255649</th>
#     <th>0.930709</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.203509</th>
#     <th>0.252857</th>
#     <th>0.931682</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.202308</th>
#     <th>0.258498</th>
#     <th>0.931308</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.200796</th>
#     <th>0.257311</th>
#     <th>0.931915</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.204560</th>
#     <th>0.251486</th>
#     <th>0.933218</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.192893</th>
#     <th>0.254977</th>
#     <th>0.932786</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.189505</th>
#     <th>0.258091</th>
#     <th>0.932555</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.190156</th>
#     <th>0.256064</th>
#     <th>0.933315</th>
#   </tr>
# </table>

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %% [markdown]
# ## fin
