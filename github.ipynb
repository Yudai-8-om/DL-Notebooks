# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from os.path import join
ROOT = '/content/gdrive'
PROJ = 'My Drive/Colab Notebooks'
GIT_USERNAME = 'Yudai-8-om'
GIT_TOKEN = '9cad00991676c5fed5dbc0a81e6129a4c7349d6c'
GIT_REPOSITORY = 'DL-Notebooks'
PROJECT_PATH = join(ROOT, PROJ)
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"

# %%
# %cd '{PROJECT_PATH}'
# !git clone "{GIT_PATH}"
# Out:
# /content/gdrive/My Drive/Colab Notebooks
# Cloning into 'DL-Notebooks'...
# ...

# %%
# !git config --global user.email "noah.bjyu@gmail.com"
# !git config --global user.name "Yudai-8-om"

# %%
# %cd DL-Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks/DL-Notebooks

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/Colab Notebooks/DL-Notebooks/.git/

# %%
! git add 202001_clothes_brand.ipynb

# %%
# !git commit -m "first commit"
# Out:
# [master (root-commit) eeaae85] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 202001_clothes_brand.ipynb

# %%
# !git remote add origin https://9cad00991676c5fed5dbc0a81e6129a4c7349d6c@github.com/Yudai-8-om/DL-Notebooks.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 827.35 KiB | 9.30 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/Yudai-8-om/DL-Notebooks.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
! git add .

# %%
# !git commit -m "commit!"
# Out:
# [master 1a8e43b] commit!
#  6 files changed, 6 insertions(+)
#  create mode 100644 Copy of lesson3-head-pose.ipynb
#  create mode 100644 Copy of lesson3-imdb.ipynb
#  create mode 100644 Copy of lesson3-planet.ipynb
#  create mode 100644 Copy of lesson4-collab.ipynb
#  create mode 100644 Copy of lesson4-tabular.ipynb
#  create mode 100644 Copy of lesson5-sgd-mnist.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 1.39 MiB | 972.00 KiB/s, done.
# Total 8 (delta 0), reused 0 (delta 0)
